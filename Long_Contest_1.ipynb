# %%
def check(string):
    stack = []
    brackets = {
        ")": "(",
        "}": "{",
        "]": "[",
    }
    for char in string:
        if not stack:
            stack.append(char)
        elif char not in brackets:
            stack.append(char)
        elif brackets[char] == stack[-1]:
            stack.pop()
        else:
            stack.append(char)
    if stack:
        print("NO")
    else:
        print("YES")    

inp = int(input().strip())
for i in range(inp):
    check(input())

# %%
class Node:
    def __init__(self,value=None):
        self.left=None
        self.right=None
        self.element=value
        
class Percentile:
  def __init__(self):
    self.m=[];self.l=[]
    self.root=None
    
  def insert(self,value):
    self.m.append(value)
    self.l.append(value)
    self.m.sort()
    if self.root==None:
        self.root=Node(value)
    else:
        temp=self.root
        while(True):
            if temp.element>=value:
                if temp.left!=None:
                    temp=temp.left
                else:
                    l=Node(value)
                    temp.left=l
                    break
            else:
                if temp.right!=None:
                    temp=temp.right
                else:
                    l=Node(value)
                    temp.right=l
                    break
                    
  def getPercentile(self,value):
    i=0
    while(i<len(self.m)):
      if(self.m[i]>=value):
        break
      i+=1
    i+=1
    return int((i*100+len(self.m)-1)/len(self.m))
    
  def hundredPercentile(self):
    return self.m[len(self.m)-1]
    
  def percGreater(self,value):
    i=0;count=0
    while(i<len(self.m)):
        if(self.getPercentile(self.m[i])>value):
           count+=1
        i+=1
    return count
        
  def pprint(self):
    self.preorderTraverse(self.root)
    print()

  def preorderTraverse(self,v):
    curnode = v
    print(curnode.element,end=" ")
    if(curnode.left!=None):
        self.preorderTraverse(curnode.left)
    if(curnode.right!=None):
        self.preorderTraverse(curnode.right)

def main():
  p=Percentile()
  tt=int(input())
  for i in range(tt):
    n=input().split(" ")
    if n[0]=='P':
      print(p.getPercentile(int(n[1])))
    elif n[0]=='I':
      p.insert(int(n[1]))
      p.pprint()
    elif n[0]=='G':
      print(p.percGreater(int(n[1])))
    else:
      print(p.hundredPercentile())

main()

# %%
import math
from collections import deque           

class BinaryTree:
    class node:
        def __init__(self):
            self.element = 0
            self.parent = None
            self.leftchild = None
            self.rightchild = None
            
    def __init__(self):
        self.sz = 0
        self.root = self.node()
        self.ht = 0
        
    def getChildren(self, curnode):
        children = []
        if curnode.leftchild != None:
            children.append(curnode.leftchild)
        if curnode.rightchild != None:
            children.append(curnode.rightchild)
        return children
        
    def isExternal(self, curnode):
        if (curnode.leftchild==None and curnode.rightchild==None):
            return (True)
        else:
            return (False)
            
    def isRoot(self,curnode):
        if (curnode.parent==None):
            return True
        else:
            return False 
            
    def inorderTraverse(self, v):
        if v!=None:
            if v.leftchild != None:
                self.inorderTraverse(v.leftchild)
            print(v.element,end=",")
            if v.rightchild != None:
                self.inorderTraverse(v.rightchild)  
            
    def preorderTraverse(self, v,lis):
        if v!=None:
            lis.append(v.element)
            if v.leftchild != None:
                self.preorderTraverse(v.leftchild,lis)
            if v.rightchild != None:
                self.preorderTraverse(v.rightchild,lis) 
            
    def postorderTraverse(self, v,lis):
        if v!=None:
            if v.leftchild != None:
                self.postorderTraverse(v.leftchild,lis)
            if v.rightchild != None:
                self.postorderTraverse(v.rightchild,lis)
            lis.append(v.element)   
        
    def levelorderTraverse(self, v,lis):
        q=deque()
        temp=v
        f=1
        while(f==1):
            lis.append(temp.element)
            if(temp.leftchild!=None):
                q.append(temp.leftchild)
            if (temp.rightchild!=None):
                q.append(temp.rightchild)
            if(len(q)>0):
                temp=q.popleft()
            else:
                f=0
        return  
   
    def mirror(self, v):
        if(v!=None):
            temp=v.leftchild
            v.leftchild=v.rightchild
            v.rightchild=temp
            self.mirror(v.leftchild)
            self.mirror(v.rightchild)   
        if v==None:
            return
        return  
            
    def buildTree(self, eltlist):
        nodelist = []
        nodelist.append(None)
        for i in range(len(eltlist)):
            if (i != 0):
                if (eltlist[i] != -1):
                    tempnode = self.node()
                    tempnode.element = eltlist[i]
                    if i != 1:
                        tempnode.parent = nodelist[i // 2]
                        if (i % 2 == 0):
                            nodelist[i // 2].leftchild = tempnode
                        else:
                            nodelist[i // 2].rightchild = tempnode
                    nodelist.append(tempnode)
                else:
                    nodelist.append(None)
        self.root = nodelist[1]
        self.sz=len(nodelist)
        return nodelist
    
    def printTree(self, nlist):
        for i in range(len(nlist)):
            if (nlist[i] != None):
                print(nlist[i].element,end=" ");
            else:
                print(None)

    def isEmpty(self):
        return (self.sz == 0)
        
    def size(self):
        return self.sz      
        
def main():
    tree = BinaryTree()
    arraySize = int(input())
    arr = list(map(int, input().split()))
    nlist = tree.buildTree(arr)
    lis=[]
    sil=[]
    opp=[]
    f=0
    tree.postorderTraverse(tree.root,lis)
    k=len(lis)
    tree.mirror(tree.root)
    tree.postorderTraverse((tree.root),opp)
    tree.preorderTraverse(tree.root,sil)
    for i in range(0,k):
        if(lis[i]==opp[i]):
            f=1
        else:
            f=0
            break
    for i in range(0,k):
        print(lis[i],end=" ")
    print()
    for i in range(0,k):
        print(sil[i],end=" ")
    print()
    if(f==1):
        print("Is a Palindromic Tree")
    else:
        print("Is Not a Palindromic Tree")
         
if __name__ == '__main__':
    main()

# %%
x=""
class postfix:
    def __init__(self, capacity):
        self.top = -1
        self.capacity = capacity
        self.array = []
        self.output = []
        self.precedence = {'+':1, '-':1, '*':2, '/':2, '^':3}

    def isEmpty(self):
        return True if self.top == -1 else False

    def peek(self):
        return self.array[-1]

    def pop(self):
        if not self.isEmpty():
            self.top -= 1
            return self.array.pop()
        else:
            return "$"

    def push(self, op):
        self.top += 1
        self.array.append(op)

    def isOperand(self, ch):
        return ch.isalpha()

    def notGreater(self, i):
        try:
            a = self.precedence[i]
            b = self.precedence[self.peek()]
            return True if a <= b else False
        except KeyError:
            return False
    def infixToPostfix(self, exp):
        for i in exp:
            if self.isOperand(i):
                self.output.append(i)
            elif i == '(':
                self.push(i)
            elif i == ')':
                while( (not self.isEmpty()) and self.peek() != '('):
                    a = self.pop()
                    self.output.append(a)
                if (not self.isEmpty() and self.peek() != '('):
                    return -1
                else:
                    self.pop()
            else:
                while(not self.isEmpty() and self.notGreater(i)):
                    self.output.append(self.pop())
                self.push(i)
        while not self.isEmpty():
            self.output.append(self.pop())
        for ele in self.output:
            global x
            x += ele
        print(x)
        x=""
        
inp = int(input())
while inp>0:
    exp= str(input())
    obj = postfix(len(exp))
    obj.infixToPostfix(exp)
    inp-=1
